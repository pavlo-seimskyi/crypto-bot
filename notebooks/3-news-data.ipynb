# %%
import os

os.chdir("../")

from dotenv import load_dotenv

# %load_ext autoreload
# %autoreload 2

load_dotenv(".env")
# Out:
# True

# %%
import black
import jupyter_black

jupyter_black.load(
    lab=False,
    line_length=79,
    verbosity="INFO",
    target_version=black.TargetVersion.PY310,
)

# %%
from datetime import datetime
import http.client, urllib.parse
import pytz
import json

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import constants

# %load_ext autoreload
# %autoreload 2

TEXT_COLOR = "#313131"
# Plotly colors
LINE_COLORS = [
    "#636EFA",
    "#EF553B",
    "#00CC96",
    "#AB63FA",
    "#FFA15A",
    "#19D3F3",
    "#FF6692",
    "#B6E880",
    "#FF97FF",
    "#FECB52",
]

sns.set(
    style="darkgrid",
    rc={
        "figure.figsize": (6, 4),
        "figure.dpi": 100,
        "figure.facecolor": "w",
        "legend.facecolor": "w",
        "text.color": TEXT_COLOR,
        "font.family": "Microsoft Sans Serif",
        "axes.labelcolor": TEXT_COLOR,
        "xtick.color": TEXT_COLOR,
        "ytick.color": TEXT_COLOR,
    },
)

sns.set_palette(sns.color_palette(LINE_COLORS))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Load news data

# %%
from src.dataloaders import MediaStackNewsScraper

# %%
scraper = MediaStackNewsScraper(keywords=["bitcoin"])

# %%
start = scraper.str_to_timestamp("2023-05-01 00:00:00")
end = scraper.str_to_timestamp("2023-05-02 00:00:00")

# %%
data = scraper.get_data_for_date("2023-05-03")

# %%
data2 = scraper.get_data_for_date("2023-05-04")

# %%
backup = data

# %%
data = scraper.load_data(start, end)

# %%
df = pd.DataFrame(data)

# %%
df["published_at"] = pd.to_datetime(df["published_at"])
# Out:
# 0    2023-05-01 19:00:18+00:00
# 1    2023-05-01 04:50:09+00:00
# 2    2023-05-01 01:40:17+00:00
# 3    2023-05-01 20:33:17+00:00
# 4    2023-05-01 07:00:10+00:00
#                 ...
# 76   2023-05-02 12:04:02+00:00
# 77   2023-05-02 00:14:13+00:00
# 78   2023-05-02 08:00:57+00:00
# 79   2023-05-02 11:44:23+00:00
# 80   2023-05-02 23:59:11+00:00
# Name: published_at, Length: 81, dtype: datetime64[ns, UTC]

# %% [markdown]
# # Load pretrained classifier

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification

model_name = "mrm8488/distilroberta-finetuned-financial-news-sentiment-analysis"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name)

# %%
from collections.abc import Iterable

# %%
def classify_text(texts, batch_size=32):
    if not isinstance(texts, Iterable) or isinstance(texts, str):
        texts = [texts]
    probs = None
    for start in range(0, len(texts), batch_size):
        end = start + batch_size
        batch = texts[start:end]
        inputs = tokenizer(batch, padding=True, truncation=True, return_tensors="pt")
        outputs = model(**inputs)
        batch_probs = outputs.logits.softmax(dim=-1)
        batch_probs = batch_probs.detach().numpy()
        batch_probs *= (0, 0.5, 1)
        if probs is None:
            probs = batch_probs
        else:
            probs = np.append(probs, batch_probs, axis=0)
    return probs.sum(axis=1)

# %%
df["description_sentiment"] = df["description"].apply(classify_text)
df["description_sentiment"] = df["description_sentiment"].apply(lambda x: x[0])

# %%
df["title_sentiment"] = df["title"].apply(classify_text)
df["title_sentiment"] = df["title_sentiment"].apply(lambda x: x[0])

# %%
# 3    0.999648
# 4    0.734107
# 5    0.499990
# 6    0.749887
# 7    0.499919
# 8    0.261741
# 9    0.018868
# 10   0.499988
# 11   0.500045
# 12   0.995807
# 13   0.001634
# 14   0.749042
# 15   0.499947
# 16   0.002247
# 17   0.001217
# 18   0.734115
# 19   0.500796
# 20   0.251326
# 21   0.500069
# 22   0.743336
# 23   0.018738
# 24   0.999445
# 25   0.500001
# 26   0.001075
# 27   0.500014
# 28   0.999697
# 29   0.999370
# 30   0.533367
# 31   0.017955
# 32   0.509622
# 33   0.749889
# 34   0.395245
# 35   0.749566
# 36   0.500512
# 37   0.500478
# 38   0.002076

# %%
for i, row in df[["title", "description", "sentiment"]].iterrows():
    print("\n")
    print(f"Sentiment: {round(row['sentiment'], 2)}")
    print(row["title"])
    # print(row["description"])
    print(30 * "= ")
# Out:
# Sentiment: 0.5
# Just Bitcoin or diversify? 5 cryptocurrencies to watch in the next few days
# = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#
#
# Sentiment: 0.0
# Bitcoin Sags After Its Longest Streak Of Monthly Gains Since 2021
# = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#
#
# Sentiment: 0.5
# Visa stablecoin plan, debt’s ceiling effect on Bitcoin price: Hodler’s Digest, April 23-29
# = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#
#
# Sentiment: 1.0
# MicroStrategy Q1 earnings beat as bitcoin impairment eases
# = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#
#
# Sentiment: 0.73
# Bitfarms Regains Compliance with Nasdaq Continued Listing Requirements
# = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#
#
# Sentiment: 0.5
# Jack Dorsey’s nano Bitcoin mining chip heads to prototype
# = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#
#
# Sentiment: 0.75
# Cathedra Bitcoin Announces Fourth Quarter and Full-Year 2022 Financial Results
# = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#
#
# Sentiment: 0.5
# Visa stablecoin plan, debt ceiling’s effect on Bitcoin price: Hodler’s Digest, April 23-29
# = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#
#
# Sentiment: 0.26
# MicroStrategy Spent $179 Million on Bitcoin Last Quarter
# = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#
#
# Sentiment: 0.02
# Bitcoin’s rise comes to a halt
# = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#
#
# Sentiment: 0.5
# BITCOIN ADDITIONAL (BTCA) Hits 24 Hour Trading Volume of $437,230.82
# = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#
#
# Sentiment: 0.5
# Bitcoin SV Achieves Market Cap of $641.13 Million (BSV)
# = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#
#
# Sentiment: 1.0
# Bitcoin Transactions Hit Weekly Record High As Ordinals Inscriptions Cross 2.7 Million Mark
# = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#
#
# Sentiment: 0.0
# Why did bitcoin go down today? Speculation on easing bank stresses
# = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#
#
# Sentiment: 0.75
# Bitcoin Talent Co. Partners With Summer of Bitcoin to Launch Summer 2023 Bitcoin Industry Apprenticeship (BIA) Program
# = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#
#
# Sentiment: 0.5
# Uncovering the Truth: Is Bitcoin Smarter a Scam or Legit Trading Platform?
# = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#
#
# Sentiment: 0.0
# Bitcoin Sags After its Longest Streak of Monthly Gains Since 2021
# = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#
#
# Sentiment: 0.0
# Bitcoin Price Prediction for Today, April 30: BTC Price Slumps in a Range Below $30K
# = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#
#
# Sentiment: 0.73
# Bitfarms Regains Compliance with Nasdaq Continued Listing Requirements
# = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#
#
# Sentiment: 0.5
# Soluna Board of Directors Unanimously Votes John Belizaire as CEO of Soluna Holdings
# = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#
#
# Sentiment: 0.25
# CFTC Fines South African More than $3.4 Billion In Largest Bitcoin Fraud Case
# = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#
#
# Sentiment: 0.5
# Bitcoin news April 2023: The good, the bad, and the HODL
# = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#
#
# Sentiment: 0.74
# Cipher Mining Announces April 2023 Operational Update
# = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#
#
# Sentiment: 0.02
# Bitcoin’s rise comes to a halt
# = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#
#
# Sentiment: 1.0
# One of World’s Largest Bitcoin Miners Reaches New Hashrate
# = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#
#
# Sentiment: 0.5
# 4 Bitcoin Teachers Offering Online Education And Free Resources
# = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#
#
# Sentiment: 0.0
# Bitcoin Lost 5.60% to $27705.32 at 5 p.m. ET -- Data Talk
# = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#
#
# Sentiment: 0.5
# Cathedra Bitcoin Announces Fourth Quarter and Full-Year 2022 Financial Results
# = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#
#
# Sentiment: 1.0
# Bitcoin posts fourth straight month of gains for first time since 2021
# = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#
#
# Sentiment: 1.0
# Bounceback: Bitcoin at $30,000 level, but surge puts $100,000 within sight
# = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#
#
# Sentiment: 0.53
# 5 Common Bitcoin Trading & Investment Pitfalls to Avoid
# = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#
#
# Sentiment: 0.02
# The Fall Of Bitcoin In The Central African Republic: Why This Legal Tender Experiment Failed
# = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#
#
# Sentiment: 0.51
# The Legality of Bitcoin in Different Countries
# = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#
#
# Sentiment: 0.75
# Cryptocurrencies Rock the Thin Market
# = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#
#
# Sentiment: 0.4
# Bitcoin Prices Fall Below $29,000. The Focus Turns to the Fed.
# = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#
#
# Sentiment: 0.75
# Unleash the Power of Bitcoin Investments with Immediate Connect’s Advanced Trading Platform
# = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#
#
# Sentiment: 0.5
# Bitcoin Erases April Gains After Slumping More Than 5% in a Day
# = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#
#
# Sentiment: 0.5
# Why Bitcoin Is Falling Today
# = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#
#
# Sentiment: 0.0
# Bitcoin Drops Below $28K; JPMorgan Takes Over Embattled First Republic Bank
# = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =

# %% [markdown]
# ---

# %% [markdown]
# # pygooglenews

# %%
from pygooglenews import GoogleNews

# %%
from datetime import datetime
from time import mktime
import pytz


def parse_struct_time(struct_time_obj):
    dt = datetime.fromtimestamp(mktime(struct_time_obj), tz=pytz.utc)
    return dt.strftime("%Y-%m-%d %H:%M:%S")

# %%
gn = GoogleNews(lang="en", country="US")

# %%
result = gn.search(
    query="bitcoin",
    #         when="1h",
    from_="2023-01-01",
    to_="2023-01-02",
)
# Out:
# https://news.google.com/rss/search?q=bitcoin+after%3A2023-01-01+before%3A2023-01-02&ceid=US:en&hl=en&gl=US

# %%
data = {
    "title": [entry["title"] for entry in result["entries"]],
    "time": [
        parse_struct_time(entry["published_parsed"]) for entry in result["entries"]
    ],
}

# %%
df = pd.DataFrame(data)

# %%
df["sentiment"] = df["title"].apply(classify_text).apply(lambda x: x[0])

# %%
df
# Out:
#                                                 title                 time
# 0   These 4 altcoins may attract buyers with Bitco...  2023-01-01 07:00:00  \
# 1   What Will It Take for Bitcoin Mining Companies...  2023-01-01 07:00:00
# 2   The Fight Against Bitcoin Starts In 2023 - Bit...  2023-01-01 07:00:00
# 3   Bitcoin Starts the New Year Off On the Wrong F...  2023-01-01 07:00:00
# 4   Markets: Bitcoin, Ethereum up, Cardano leads g...  2023-01-01 07:00:00
# 5   Veteran Bitcoin Developer: Keys to $3.6M in BT...  2023-01-02 07:00:00
# 6   How Bitcoin Price Could Hit $23 Million If $BT...  2023-01-01 07:00:00
# 7   The centralization of Bitcoin: Behind the two ...  2023-01-01 07:00:00
# 8   Valkyrie Reveals Intention to Sponsor Grayscal...  2023-01-01 07:00:00
# 9   Rich Dad Poor Dad Author Robert Kiyosaki is Bu...  2023-01-01 07:00:00
# 10  Big Eyes Coin on the Verge of Breakthrough As ...  2023-01-01 07:00:00
#
#     sentiment
# 0    0.002758
# 1    0.499974
# 2    0.499990
# 3    0.499979
# 4    0.999721
# 5    0.500026
# 6    0.998785
# 7    0.499984
# 8    0.500005
# 9    0.500016
# 10   0.500005

# %%
# Title lengths, seems to be capped
[len(t) for t in df["title"]]
# Out:
# [75, 77, 59, 61, 66, 72, 83, 112, 85, 83, 89]
